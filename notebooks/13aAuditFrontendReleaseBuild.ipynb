# %% [markdown]
# # 13a — Audit Frontend Release Build\n\nRead-only M13 bundle audit. It does not regenerate ranking, candidates, embeddings, or release projection.\n

# %%
from pathlib import Path
import json, sys
REPO_ROOT = Path.cwd().resolve().parent
sys.path.insert(0, str(REPO_ROOT))
qa = REPO_ROOT / 'data/80_quality/mbn/m13/run_20260808_m13_minimal_safe_release_v1_1'
gate = json.loads((qa / 'm13_final_gate.json').read_text(encoding='utf-8'))
gate
# Out:
# {'m13Gate': 'M13_RELEASE_BUILT_WITH_WARNINGS',
#  'releaseId': 'mbn-guide-dc9f6a80d54985d6',
#  'checks': {'projectedPlaceCount': 19,
#   'projectedArticleCount': 461,
#   'brokenFK': 0,
#   'invalidCoordinates': 0,
#   'missingWhyItMatters': 0,
#   'missingReason': 0,
#   'secretLeak': 0,
#   'silentRecommendationLoss': 0},
#  'frontendReady': 'NOT_DECLARED'}
