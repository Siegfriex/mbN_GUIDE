# %% [markdown]
# # 11 — Build recommendation candidates
#
# M11 unions existing M9 semantic retrieval and M7 direct/geo relations. It does not calculate a final score, ranking, recommendation reason, Provider call, or model embedding.

# %%
from pathlib import Path
import sys
REPO_ROOT=Path.cwd().resolve().parent;sys.path.insert(0,str(REPO_ROOT))
from src.text.m11_candidates import run_m11
m11_gate=run_m11(REPO_ROOT);m11_gate
# Out:
# {'m11Gate': 'M11_CANDIDATE_READY',
#  'checks': {'duplicateCandidatePK': 0,
#   'brokenContextFK': 0,
#   'brokenTargetFK': 0,
#   'selfTarget': 0,
#   'nonMapEntityPromoted': 0,
#   'expiredEventPromoted': 0,
#   'finalScoreColumnPresent': 0,
#   'rankingColumnViolation': 0},
#  'counts': {'candidates': 13084,
#   'evidence': 13146,
#   'eligible': 13001,
#   'eligibleWithMissingFeature': 83,
#   'hold': 0,
#   'ineligible': 0,
#   'c3SemanticDroppedByConfiguredCap': 1078},
#  'manifestHashMismatch': 0}
