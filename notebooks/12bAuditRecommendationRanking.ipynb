# %% [markdown]
# # 12b — Independent M12 ranking audit
#
# Checks ranking continuity, selected-reason coverage, and fixed-sample formula/MMR audit outcomes without candidate retrieval.

# %%
from pathlib import Path
import sys
REPO_ROOT=Path.cwd().resolve().parent;sys.path.insert(0,str(REPO_ROOT))
from src.text.m12_ranking import audit_m12
m12_audit=audit_m12(REPO_ROOT);m12_audit
# Out:
# {'audit': 'M12_INDEPENDENT_SAMPLE_AUDIT',
#  'formulaSampleRows': 300,
#  'baseFormulaMismatch': 0,
#  'mmrFormulaMismatch': 0,
#  'missingReason': 0,
#  'auditVerdict': 'M12_AUDIT_PASS'}
