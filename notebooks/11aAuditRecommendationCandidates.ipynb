# %% [markdown]
# # 11a — Independent candidate integrity audit
#
# This audit checks candidate/evidence grains, orphan evidence, and the explicit no-final-score boundary without rerunning retrieval.

# %%
from pathlib import Path
import sys
REPO_ROOT=Path.cwd().resolve().parent;sys.path.insert(0,str(REPO_ROOT))
from src.text.m11_candidates import audit_m11
m11_audit=audit_m11(REPO_ROOT);m11_audit
# Out:
# {'audit': 'M11_DETERMINISTIC_AUDIT',
#  'candidatePkDuplicate': 0,
#  'orphanEvidence': 0,
#  'missingDirectRelation': 0,
#  'configuredC3CapDrop': 1078,
#  'finalScoreColumnPresent': 0,
#  'formulaMismatchCount': 0,
#  'auditVerdict': 'M11_AUDIT_PASS'}
