# %% [markdown]
# # 08a — Local embedding benchmark
#
# Authority: `WEAK_RETRIEVAL_BENCHMARK`. This compares local encoders only; it neither creates semantic relations nor calls a remote inference API.

# %%
from pathlib import Path
import sys
REPO_ROOT = Path.cwd().resolve().parent
sys.path.insert(0, str(REPO_ROOT))
from src.text.m8_embeddings import benchmark_models, output_root
results, selection, table = benchmark_models(REPO_ROOT, output_root(REPO_ROOT))
display(results)
display(table)
selection
# Out:
#    queryCount  recallAt1  recallAt5  recallAt10       mrr  \
# 0         461   0.290672   0.464208    0.533623  0.374271
# 1          25   0.200000   0.520000         NaN  0.352207
# 2         461   0.629067   0.830803    0.889371  0.724886
# 3          25   0.560000   0.920000         NaN  0.686833
# 4         461   0.902386   0.991323    0.997831  0.940582
# 5          25   0.600000   0.800000         NaN  0.693406
#
#                                              modelId  \
# 0  sentence-transformers/paraphrase-multilingual-...
# 1  sentence-transformers/paraphrase-multilingual-...
# 2                     intfloat/multilingual-e5-small
# 3                     intfloat/multilingual-e5-small
# 4                                        BAAI/bge-m3
# 5                                        BAAI/bge-m3
#
#                         task  wallSeconds  textsPerSecond device  dimension  \
# 0          TITLE_TO_OWN_BODY    11.931818      130.323809   cuda          0
# ...
