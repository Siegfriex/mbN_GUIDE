# %% [markdown]
# # 12 — Rank culture recommendations
#
# Candidate-only, explainable, availability-aware ranking. M11 retrieval is not rerun; no provider, LLM, embedding inference, popularity, personalization, or frontend release occurs.

# %%
from pathlib import Path
import sys
REPO_ROOT=Path.cwd().resolve().parent;sys.path.insert(0,str(REPO_ROOT))
from src.text.m12_ranking import run_m12
m12_gate=run_m12(REPO_ROOT);m12_gate
# Out:
# {'m12Gate': 'M12_RANKING_READY',
#  'checks': {'candidateLoss': 0,
#   'duplicateRecommendation': 0,
#   'rankGaps': 0,
#   'selectedTopKMismatch': 0,
#   'missingReasonSelected': 0,
#   'reasonEvidenceMismatch': 0,
#   'baseFormulaMismatch': 0,
#   'mmrFormulaMismatch': 0,
#   'nan': 0,
#   'inf': 0,
#   'm10AuthorityLeakage': 0,
#   'fakePopularity': 0,
#   'fakePersonalization': 0,
#   'sponsoredBoost': 0},
#  'manifestHashMismatch': 0}
