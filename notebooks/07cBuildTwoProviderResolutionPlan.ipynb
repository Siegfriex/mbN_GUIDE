# %% [markdown]
# # 07c — Two-provider resolution plan
#
# Routes only evidence-safe M7 queries. This notebook does not call either provider.

# %%
from pathlib import Path
import sys
REPO_ROOT=Path.cwd().resolve().parent; sys.path.insert(0,str(REPO_ROOT))
from src.geo.m7_tourapi import build_routes
RUN_ROOT=REPO_ROOT/'data/30_geo/mbn/m7/run_20260808_m7_geo'
routes=build_routes(RUN_ROOT)
print(routes.groupby(['route','operation']).size())
# Out:
# route         operation
# TOUR_KEYWORD  searchKeyword2    265
# dtype: int64
