# %% [markdown]
# # 10 — Classify culture content
#
# Frozen M8/M9 artifacts are reused.  No corpus re-embedding, LLM, Provider, or ranking action occurs.  The available taxonomy authority is the observed normalized MBN editorial-label contract; no DOCS semantic taxonomy was present.

# %%
from pathlib import Path
import sys
REPO_ROOT=Path.cwd().resolve().parent; sys.path.insert(0,str(REPO_ROOT))
from src.text.m10_classification import run_m10
m10_gate=run_m10(REPO_ROOT);m10_gate
# Out:
# {'m10Gate': 'M10_CLASSIFICATION_READY',
#  'taxonomyAuthority': 'OBSERVED_MBN_EDITORIAL_LABEL_CONTRACT; HIGH_CONFIDENCE_TAXONOMY_SILVER only',
#  'counts': {'articles': 461,
#   'taxonomyClasses': 58,
#   'confirmed': 461,
#   'provisional': 0,
#   'unknown': 0,
#   'conflict': 0},
#  'checks': {'invalidTaxonomy': 0,
#   'brokenEvidenceFK': 0,
#   'prototypeLeakage': 0,
#   'formulaMismatch': 0},
#  'manifestHashMismatch': 0}
