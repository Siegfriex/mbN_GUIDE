# %% [markdown]
# # 07 — Canonical M7 Geocode Places
#
# Offline replay only: validated TourAPI snapshots, fingerprints, observations, and decisions are replayed without another provider request.

# %%
from pathlib import Path
import sys
REPO_ROOT=Path.cwd().resolve().parent; sys.path.insert(0,str(REPO_ROOT))
from src.geo.m7_replay import replay_and_compare
result=replay_and_compare(REPO_ROOT)
assert result['verdict']=='M7_CANONICAL_REPLAY_PASS'
print(result)
# Out:
# {'sourceCounts': {'places': 25, 'events': 7, 'mapEligible': 32, 'articlePlaceRelations': 40, 'articleEventRelations': 8}, 'replayCounts': {'places': 25, 'events': 7, 'mapEligible': 32, 'articlePlaceRelations': 40, 'articleEventRelations': 8}, 'semanticEquivalent': True, 'verdict': 'M7_CANONICAL_REPLAY_PASS'}
