# %% [markdown]
# # 10a — Independent M10 audit
#
# Checks grain, evidence linkage, and status semantics without rebuilding representations or running a model.

# %%
from pathlib import Path
import sys
REPO_ROOT=Path.cwd().resolve().parent; sys.path.insert(0,str(REPO_ROOT))
from src.text.m10_classification import audit_m10
m10_audit=audit_m10(REPO_ROOT);m10_audit
# Out:
# {'audit': 'M10_DETERMINISTIC_AUDIT',
#  'articlePkDuplicate': 0,
#  'confirmedWithoutEvidence': 0,
#  'formulaMismatchCount': 0,
#  'auditVerdict': 'M10_AUDIT_PASS'}
